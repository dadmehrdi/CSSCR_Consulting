# %%
import pandas as pd

# Load your data (this step depends on your file format)
file_path = '/Users/dadmehr/Codes/Python/Past/Call_Data_20240130.csv'
data = pd.read_csv(file_path)

# replacing '--' with nothing in the 'Final Call Type' column
data['Final Call Type'] = data['Final Call Type'].str.replace('--', '')

# %%
#data

# %%
# Now save the modified DataFrame back to a new CSV file
output_file_path = '/Users/dadmehr/Codes/Python/Past/modified_Call_Data_20240130.csv'
data.to_csv(file_path, index=False)

# 'index=False' is used to prevent pandas from writing row indices into the CSV file

# %%
contains_2024 = data['Original Time Queued'].str.contains('2024', case=False, na=False)
data_2024 = data[contains_2024]

# %%
data_2024
# Out:
#          CAD Event Number             Event Clearance Description  \
# 90          2024000004875               FALSE COMPLAINT/UNFOUNDED
# 428         2024000009965              REPORT WRITTEN (NO ARREST)
# 433         2024000005498                     ASSISTANCE RENDERED
# 519         2024000022405                   FOLLOW-UP REPORT MADE
# 535         2024000020246                   FOLLOW-UP REPORT MADE
# ...                   ...                                     ...
# 5653703     2024000004446              REPORT WRITTEN (NO ARREST)
# 5653842     2024000006723              REPORT WRITTEN (NO ARREST)
# 5654645     2024000008128  NO POLICE ACTION POSSIBLE OR NECESSARY
# 5654764     2024000017724                     ASSISTANCE RENDERED
# 5654854     2024000017148              REPORT WRITTEN (NO ARREST)
#
#                         Call Type  Priority  \
# 90       TELEPHONE OTHER, NOT 911       2.0
# 428                           911       5.0
# 433                        ONVIEW       9.0
# 519                        ONVIEW       3.0
# 535                        ONVIEW       3.0
# ...                           ...       ...
# 5653703                    ONVIEW       3.0
# 5653842                       911       3.0
# 5654645                    ONVIEW       3.0
# 5654764                       911       1.0
# 5654854  TELEPHONE OTHER, NOT 911       5.0
#
#                                   Initial Call Type  \
# 90       ALARM - COMM, HOLD-UP/PANIC (EXCEPT BANKS)
# 428                         TRU - MVC - HIT AND RUN
# 433                             OFF DUTY EMPLOYMENT
# 519                               PROPERTY - DAMAGE
# 535                                       FOLLOW UP
# ...                                             ...
# 5653703                               AUTO RECOVERY
# 5653842   ORDER - VIOLATION OF COURT ORDER (NON DV)
# 5654645    PARKING VIOLATION (EXCEPT ABANDONED CAR)
# 5654764            OVERDOSE - DRUG RELATED CASUALTY
# 5654854                               TRU - THREATS
#
#                                        Final Call Type  \
# 90            ALARM-COMM (INC BANK, ATM, SCHOOLS, BSN)
# 428               TRAFFIC - MV COLLISION INVESTIGATION
# 433                               -OFF DUTY EMPLOYMENT
# 519                               PROPERTY DEST (DAMG)
# 535                 BURGLARY - RESIDENTIAL, UNOCCUPIED
# ...                                                ...
# 5653703                      PROPERTY - FOUND PROPERTY
# 5653842                  ASSAULTS - TELEPHONE, WRITING
# 5654645  TRAFFIC - PARKING VIOL (EXCEPT ABANDONED CAR)
# 5654764          ASSIST PUBLIC - OTHER (NON-SPECIFIED)
# 5654854  THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)
#
#            Original Time Queued            Arrived Time   Precinct   Sector  \
# 90       01/06/2024 02:23:03 AM  01/06/2024 02:34:14 AM       EAST   EDWARD
# 428      01/11/2024 02:40:00 PM  01/11/2024 03:32:22 PM      NORTH      BOY
# 433      01/06/2024 07:03:28 PM  01/06/2024 07:03:28 PM      SOUTH      SAM
# 519      01/24/2024 05:33:42 PM  01/24/2024 05:33:42 PM      SOUTH      SAM
# 535      01/22/2024 04:07:43 PM  01/22/2024 04:07:43 PM      SOUTH      SAM
# ...                         ...                     ...        ...      ...
# 5653703  01/05/2024 04:08:46 PM  01/05/2024 04:08:46 PM  SOUTHWEST    FRANK
# 5653842  01/08/2024 10:17:17 AM  01/08/2024 10:39:32 AM  SOUTHWEST  WILLIAM
# 5654645  01/09/2024 05:37:03 PM  01/09/2024 05:37:03 PM      NORTH     NORA
# 5654764  01/19/2024 09:33:06 PM  01/19/2024 09:34:59 PM       WEST     MARY
# 5654854  01/19/2024 10:00:13 AM  01/19/2024 10:41:15 AM       WEST    QUEEN
#
#         Beat  Blurred_Longitude  Blurred_Latitude
# 90        E1        -122.325297         47.620242
# 428       B2        -122.354984         47.652361
# 433       S2          -1.000000         -1.000000
# 519       S1        -122.282968         47.515702
# 535       S1        -122.281440         47.515258
# ...      ...                ...               ...
# 5653703   F1        -122.362150         47.535515
# 5653842   W1        -122.385210         47.580246
# 5654645   N1        -122.367713         47.720583
# 5654764   M3        -122.337793         47.609750
# 5654854   Q2        -122.376208         47.652299
#
# [22918 rows x 13 columns]

# %%
#pip install folium

# %%
import folium

# Initialize a map centered on UW
map = folium.Map(location=[47.655334, -122.303520], zoom_start=14) # Adjust zoom level as needed



data_2024_UW = data_2024[(data_2024['Blurred_Latitude'] < 47.675) &
                         (data_2024['Blurred_Latitude'] > 47.645) & 
                         (data_2024['Blurred_Longitude'] < -122.275) &
                         (data_2024['Blurred_Longitude'] > -122.32)]


# Add points to the map
for idx, row in data_2024_UW.iterrows():  # And here
    folium.CircleMarker(
        location=[row['Blurred_Latitude'], row['Blurred_Longitude']],
        radius=.3,  # Adjust the size of the circle markers
        popup=row['Final Call Type'],  # This can be any column in your DataFrame
        fill=True
    ).add_to(map)

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cedb3b969919b9a96fa766d0699b57f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cedb3b969919b9a96fa766d0699b57f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cedb3b969919b9a96fa766d0699b57f = L.map(
#                 &quot;map_4cedb3b969919b9a96fa766d0699b57f&quot;,
#                 {
#                     center: [47.655334, -122.30352],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c68c9e18e58c60133f9a041792534f17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c68c9e18e58c60133f9a041792534f17.addTo(map_4cedb3b969919b9a96fa766d0699b57f);
#
#
#             var circle_marker_3f355a3956620cb8093b914eb684ef12 = L.circleMarker(
#                 [47.66493734, -122.31740379],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cedb3b969919b9a96fa766d0699b57f);
#
#
#         var popup_ee95cfa3e9fd5ace0070bbb3a39ce0ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_441f08fab2e3ba5728d5b5bc481503a7 = $(`&lt;div id=&quot;html_441f08fab2e3ba5728d5b5bc481503a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TRAFFIC - ASSIST MOTORIST&lt;/div&gt;`)[0];
#                 popup_ee95cfa3e9fd5ace0070bbb3a39ce0ed.setContent(html_441f08fab2e3ba5728d5b5bc481503a7);
#
#
#
#         circle_marker_3f355a3956620cb8093b914eb684ef12.bindPopup(popup_ee95cfa3e9fd5ace0070bbb3a39ce0ed)
#         ;
#
#
#
#
#             var circle_marker_7b064233a777887f5a2085d0ddde7874 = L.circleMarker(
#                 [47.66214634, -122.28476385],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cedb3b969919b9a96fa766d0699b57f);
#
#
#         var popup_8b5e317b6067d8b2bb53cba3d4293ba5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_304fa8661d18ea897b2a9c1a90824b41 = $(`&lt;div id=&quot;html_304fa8661d18ea897b2a9c1a90824b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DISTURBANCE - NOISE&lt;/div&gt;`)[0];
#                 popup_8b5e317b6067d8b2bb53cba3d4293ba5.setContent(html_304fa8661d18ea897b2a9c1a90824b41);
#
#
#
#         circle_marker_7b064233a777887f5a2085d0ddde7874.bindPopup(popup_8b5e317b6067d8b2bb53cba3d4293ba5)
#         ;
#
#
#
#
#             var circle_marker_792b02c6846b2aa484b4f9ae17bddbdb = L.circleMarker(
#                 [47.64556132, -122.30583314],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4cedb3b969919b9a96fa766d0699b57f);
#
#
#         var popup_25469d2bbdefc096b7de014940d06d39 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_28cb0bcfdc3c8a1acbc920de4fb4e334 = $(`&lt;div id=&quot;html_28cb0bcfdc3c8a1acbc920de4fb4e334&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TRAFFIC - PARKING VIOL (EXCEPT ABANDONED CAR)&lt;/div&gt;`)[0];
#                 popup_25469d2bbdefc096b7de014940d06d39.setContent(html_28cb0bcfdc3c8a1acbc920de4fb4e334);
#
#
#
#         circle_marker_792b02c6846b2aa484b4f9ae17bddbdb.bindPopup(popup_25469d2bbdefc096b7de014940d06d39)
#         ;
#
#
#
#
#             var circle_marker_30d61506cf744f1bba437fa9ceb4e1fc = L.circleMarker(
#                 [47.66219773, -122.31538809],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot
