# %%
import pandas as pd

# Load your data (this step depends on your file format)
file_path = '/Users/dadmehr/Codes/Python/Past/Call_Data_20240130.csv'
data = pd.read_csv(file_path)

# replacing '--' with nothing in the 'Final Call Type' column
data['Final Call Type'] = data['Final Call Type'].str.replace('--', '')

# %%
data
# Out:
#          CAD Event Number               Event Clearance Description  \
# 0           2011000181574                       ASSISTANCE RENDERED
# 1           2009000398868                       ASSISTANCE RENDERED
# 2           2010000433524                REPORT WRITTEN (NO ARREST)
# 3           2010000433306                       ASSISTANCE RENDERED
# 4           2010000433342                        ORAL WARNING GIVEN
# ...                   ...                                       ...
# 5654879     2020000117647                REPORT WRITTEN (NO ARREST)
# 5654880     2015000322794                REPORT WRITTEN (NO ARREST)
# 5654881     2011000257127  UNABLE TO LOCATE INCIDENT OR COMPLAINANT
# 5654882     2021000199788                       ASSISTANCE RENDERED
# 5654883     2015000419133                 FALSE COMPLAINT/UNFOUNDED
#
#                         Call Type  Priority  \
# 0                             911       2.0
# 1                          ONVIEW       4.0
# 2        TELEPHONE OTHER, NOT 911       3.0
# 3                          ONVIEW       4.0
# 4                          ONVIEW       7.0
# ...                           ...       ...
# 5654879                       911       2.0
# 5654880                       911       2.0
# 5654881                       911       2.0
# 5654882                       911       2.0
# 5654883                       911       1.0
#
#                                          Initial Call Type  \
# 0                                        PROPERTY - DAMAGE
# 1                                         REQUEST TO WATCH
# 2               AUTO THEFT - VEH THEFT OR THEFT & RECOVERY
# 3                                         REQUEST TO WATCH
# 4                  TRAFFIC STOP - OFFICER INITIATED ONVIEW
# ...                                                    ...
# 5654879                                DIST - DV - NO ASLT
# 5654880                         MVC - NON INJURY, BLOCKING
# 5654881   NARCOTICS - VIOLATIONS (LOITER, USE, SELL, NARS)
# 5654882                                           TRESPASS
# 5654883  UNKNOWN - ANI/ALI - LANDLINE (INCLUDES OPEN LINE)
#
#                                  Final Call Type    Original Time Queued  \
# 0         SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON  06/07/2011 12:06:53 AM
# 1              PREMISE CHECKS - CRIME PREVENTION  11/15/2009 04:06:06 AM
# 2                       AUTOMOBILES - AUTO THEFT  12/17/2010 09:37:44 AM
# 3              PREMISE CHECKS - CRIME PREVENTION  12/17/2010 04:07:10 AM
# 4                     TRAFFIC - MOVING VIOLATION  12/17/2010 04:51:37 AM
# ...                                          ...                     ...
# 5654879  DV - ARGUMENTS, DISTURBANCE (NO ARREST)  04/08/2020 12:38:10 AM
# 5654880     TRAFFIC - MV COLLISION INVESTIGATION  09/14/2015 03:58:13 PM
# 5654881   SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON  08/06/2011 09:48:44 PM
# 5654882    ASSIST PUBLIC - OTHER (NON-SPECIFIED)  08/03/2021 09:42:45 PM
# 5654883   ASSIST PUBLIC - 911 HANG UP, OPEN LINE  12/02/2015 04:36:31 PM
#
#                    Arrived Time Precinct Sector Beat  Blurred_Longitude  \
# 0        06/07/2011 12:46:09 AM     WEST  QUEEN   Q1        -122.413381
# 1        11/15/2009 04:06:06 AM     WEST   KING   K1          -1.000000
# 2        12/17/2010 10:01:34 AM     WEST   KING   K2        -122.334854
# 3        12/17/2010 04:07:10 AM     WEST   KING   K2        -122.331124
# 4        12/17/2010 04:51:37 AM     WEST   KING   K2        -122.331576
# ...                         ...      ...    ...  ...                ...
# 5654879  04/08/2020 12:43:11 AM     WEST   KING   K3        -122.328966
# 5654880  09/14/2015 04:20:59 PM     WEST  DAVID   D2           0.000000
# 5654881  08/06/2011 10:08:56 PM     WEST   MARY   M1        -122.341960
# 5654882  08/03/2021 10:17:42 PM     WEST  DAVID   D2        -122.338382
# 5654883  12/02/2015 04:44:32 PM     WEST  DAVID   D3        -122.334277
#
#          Blurred_Latitude
# 0               47.653399
# 1               -1.000000
# 2               47.600885
# 3               47.601718
# 4               47.599621
# ...                   ...
# 5654879         47.599616
# 5654880          0.000000
# 5654881         47.610682
# 5654882         47.617939
# 5654883         47.622581
#
# [5654884 rows x 13 columns]

# %%
# Now save the modified DataFrame back to a new CSV file
output_file_path = '/Users/dadmehr/Codes/Python/Past/modified_Call_Data_20240130.csv'
data.to_csv(file_path, index=False)

# 'index=False' is used to prevent pandas from writing row indices into the CSV file
